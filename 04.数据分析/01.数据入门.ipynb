# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('data/movie.csv')
#展示中文
plt.rcParams['font.sans-serif'] = ['SimHei']
df.isnull().sum()
# Out:
# 名字      0
# 年份      0
# 上映时间    0
# 类型      0
# 时长      0
# 名句      0
# 简介      0
# dtype: int64
